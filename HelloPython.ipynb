# %% [markdown]
# Hello Python! This is my first Notebook!

# %%
print ("Hello World!")
# Out:
# Hello World!

# %%
print (2*4)
# Out:
# 8

# %%
print ("Hello chat!")
print ("TACC is sugoi!")
print ("i <3 u")
# Out:
# Hello chat!
# TACC is sugoi!
# i <3 u

# %%
2.3 +6
# Out:
# 8.3

# %%
name = "Alan"
Name = "Mason"
print (name)
# Out:
# Alan

# %%
print (Name)
# Out:
# Mason

# %%
1num = 7
# Out:
#   File "<ipython-input-8-010229339cf8>", line 1
#     1num = 7
#      ^
# SyntaxError: invalid syntax

# %%
num = 5

# %%
print (num)
# Out:
# 5

# %%
a = "hello"
b= True
num1 = 5
type (a)
# Out:
# str

# %%
myfile= open("test.dat",'xyz')
myfile.write(num)
myfile.write("\n")
myfile.write("HelloWorld")
myfile.close
# Out:
#   File "<ipython-input-16-50c6ff02d9ef>", line 3
#     myfile.write(\n)
#                     ^
# SyntaxError: unexpected character after line continuation character

# %%
for i in range (1, 3):
    for j in range (1,4):
        print (i,j)
# Out:
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3

# %%
mylist= ["Alan", 7, "blue", "sugoi", 17, "chud"]
for t in mylist:
    print(t,type (t))
# Out:
# Alan <class 'str'>
# 7 <class 'int'>
# blue <class 'str'>
# sugoi <class 'str'>
# 17 <class 'int'>
# chud <class 'str'>

# %%
print (mylist[0:3])
# Out:
# ['Alan', 7, 'blue']

# %%
print (mylist[-2])
# Out:
# 17

# %%
print (mylist[3:])
# Out:
# ['sugoi', 17, 'chud']

# %%
import math

def calc_hyp (a,b):
    h = math.sqrt(a*a + b*b)
    return h

# %%
my_h= calc_hyp (3,4)
print (my_h)
# Out:
# 5.0
