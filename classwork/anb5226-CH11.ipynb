# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline

# %%
# Define known data points
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 1, 0, 1, 0, 1])
# Create a cubic spline interpolation of the data
cs = CubicSpline(x, y, bc_type='natural')
# Generate new x values for a smooth plot
x_interp = np.linspace(0, 5, 100)
y_interp = cs(x_interp)

# %%
#polyfit
coeffs= np.polyfit(x,y,5)
poly= np.poly1d(coeffs)
y_poly= poly(x_interp)

# %%
#plotting
plt.figure()
plt.plot(x,y,'o', label="Data Points")
plt.plot(x_interp, y_interp, label="Spline Graph")
plt.plot(x_interp, y_poly, label= "Poly Graph")
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Cubic Spline vs Poly Graph")
plt.legend()
plt.show()

# %% [markdown]
# Both graphs will go through all the points that were listed. However, the spline graph has less of a peak and trough through its oscillations. The spline graph is better for going through points that have a lot of variance in direction. Additionally, when using the polyfit, degrees that are less than n-1 the number of points will fail to go through all the points, and those with degrees greater than n-1 will show a poor execution toward the end of the graph, often having a high oscillation right before the last couple points.
