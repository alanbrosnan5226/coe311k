# %%
i = 1**32
print (i)
# Out:
# 1

# %%
i+2**-53
# Out:
# 1.0

# %%
print ("diddy foid")
# Out:
# diddy foid

# %%
def diddy(x):
    if (x>0):
        print ("foid")
        
    elif (x<0):
        print ("chud")
        
    else:
        print ("choid")

# %%
diddy(-3)
# Out:
# chud
