# %%
import numpy as np
import matplotlib.pyplot as plt
import random as rand

# %%
# Data points 

X = np.array([1, 2, 3, 4, 5])

Y = np.array([1.2, 2.8, 3.6, 4.5, 5.1])

# Stack the design matrix with a column of ones (for the intercept)

A = np.vstack([X, np.ones(len(X))]).T

# Solve using least squares

m, c = np.linalg.lstsq(A, Y, rcond=None)[0]

print(f"Slope: {m}, Intercept: {c}")

#plot the data points and the best-fit line
# Out:
# Slope: 0.9500000000000001, Intercept: 0.5900000000000001

# %%
x= np.linspace(0,max(X),100)
lstsq= m*x+c
plt.title ("Least Square Regression Between the given Data Points")
plt.scatter (X,Y)
plt.plot(x,lstsq)
plt.xlabel("x")
plt.ylabel("y")
plt.show()
# Out:
# Text(0, 0.5, 'y')

# %%
#Randomize vectors x and y
Xrand= np.random.rand(X.size)
Yrand= np.random.rand(Y.size)
idx= np.argsort(Xrand)
Xrand= Xrand[idx]
Yrand= Yrand[idx]
print ("Randomized X Vector:", Xrand)
print ("Randomized Y Vector:", Yrand)

B= np.vstack([Xrand, np.ones(len(Xrand))]).T
n,d =np.linalg.lstsq(B,Yrand,rcond=None)[0]
print ("Slope:", n, "Intercept:", d)
# Out:
# Randomized X Vector: [0.02464938 0.07283987 0.36296271 0.58035097 0.7817601 ]
# Randomized Y Vector: [0.60881836 0.74424771 0.63542448 0.19888758 0.57271552]
# Slope: -0.33965604770425384 Intercept: 0.6758276408766366

# %%
x=np.linspace(Xrand.min(), Xrand.max(), 100)
y= n*x+d
plt.title("Least Square Regression Model of Randomized Vectors")
plt.xlabel("x")
plt.ylabel("y")
plt.scatter(Xrand, Yrand)
plt.plot (x, y)
plt.show()

# %%
#DO PORTION NUMBER 3 LATER
#Randomization
X1=np.arange(0,1.01,.01)
m= np.random.rand()
b= np.random.rand()
Y= m*X1+b+np.random.rand(X1.size)
print ("Random Slope: ", m, "Random Intercept: ", b)


#Lin alg
B= np.vstack([X1, np.ones(len(X1))]).T
n,d =np.linalg.lstsq(B,Y,rcond=None)[0]
print ("Calculated Slope:", n, "Calculated Intercept:", d)

#Residuals
residuals= Y-(n*X1+d)
max_residual= np.argmax(residuals)
min_residual= np.argmin(residuals)
print ("Max Residual: ", residuals[max_residual], "at point X= ", X1[max_residual])
print ("Min Residual: ", residuals[min_residual], "at point X= ", X1[min_residual],"\n")

#print all residuals
print("Every Residual:")
for i in range (len(residuals)):
    print(residuals[i])

plt.title("Least Square Regression Model of Own Linear Equation")
plt.xlabel("x")
plt.ylabel("y")
plt.plot(X1,n*X1+ d)
plt.scatter(X1, Y)
plt.show()
# Out:
# Random Slope:  0.32008910195073437 Random Intercept:  0.48195826808566855
# Calculated Slope: 0.36089156136000483 Calculated Intercept: 1.0124575310510815
# Max Residual:  0.45456602168761795 at point X=  0.16
# Min Residual:  -0.5290963517701028 at point X=  0.99
#
# Every Residual:
# -0.17023106411567257
# -0.08785979610029804
# 0.0016855159290221078
# 0.14811180664295276
# -0.061751318085909945
# 0.42720945305319313
# 0.20064010691376355
# -0.16776037882564931
# -0.035801767761051595
# 0.16676847383967175
# -0.2638031815199593
# -0.0083298731487369
# -0.3221676099522164
# -0.46110104328307266
# 0.1530882792430448
# -0.2980688992037154
# 0.45456602168761795
# -0.16069228585628326
# -0.12062350532927268
# -0.23299603994546148
# 0.29929101916424594
# -0.11269688551891843
# 0.3740050091122835
# 0.44146913317031355
# 0.3727316300347392
# 0.38013164267697697
# 0.20749014976998303
# 0.1397762978631476
# 0.43395376528408036
# -0.3116301498465196
# -0.211218317780013
# -0.2922945266475968
# 0.1533215467745621
# -0.38168975329796606
# -0.1482331350519378
# 0.33510260035019623
# -0.46771620979227624
# -0.458595060269684
# -0.32367694029913163
# -0.343317416205814
# 0.17935287173269043
# 0.4393119855777248
# -0.4828888695471377
# 0.28138659893440643
# -0.3434245637334312
# -0.10408993937120559
# 0.406278004477745
# 0.1033203235323179
# -0.13576263746428752
# 0.3719336987832682
# 0.26617880655332904
# -0.32269315975856705
# -0.01899056031948243
# -0.21163613905650513
# 0.4139984094946365
# 0.3277883145518856
# -0.32455383374226965
# -0.2964713935103971
# -0.293315504899912
# 0.11933232816745742
# -0.005215118060378776
# 0.3278243804222978
# -0.33890193619213216
# 0.008038516069532431
# 0.3586569504402195
# -0.48513819473463193
# -0.1561990384156935
# -0.09533192297301296
# 0.40963446829898276
# -0.178928133492553
# 0.33989266410079133
# -0.47727781164206406
# 0.17213952507437602
# -0.17456900210489845
# 0.38313205153481156
# 0.2197401253678477
# 0.2501735934822684
# -0.44500972804783834
# 0.07556885286209347
# 0.2828066220423917
# -0.04374378188287631
# -0.5242445665794755
# 0.414020796588942
# 0.05880461843171081
# 0.16360334452607406
# -0.2194661816267185
# -0.31936914750117684
# 0.4185714227047961
# 0.40574405384235446
# 0.2115819196926747
# -0.19581225622924547
# 0.35407873822722635
# -0.05831068824323338
# -0.08725592647437397
# -0.02340633429084349
# -0.16944764316511973
# -0.3718033017099236
# 0.3061341615235915
# 0.04841558935817103
# -0.5290963517701028
# 0.06782263647029119
