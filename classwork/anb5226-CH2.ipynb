# %%
def ConversionToBinary (x):
    #Create empty array
    #have it run through the value of x adding a value to each of the elemnts in the array
    #Reverse the array in order to get the output of the binary code
    #Read the array "".join(str(z)for z in bit)


        if (x==0):
            print ("0")

        elif (x>0):
            bit= []
            while(x>0):
                    remainder= x%2
                    x=x//2
                    bit.append(remainder)
        
            bit.reverse()

            print ("".join(str(b)for b in bit))

# %%
ConversionToBinary(2025)
# Out:
# 11111101001
